# %%
import pandas as pd

# %%
# load adni-freesurfer_3_11_2025.csv and final_adni_qc.csv as dataframes
freesurfer = pd.read_csv('adni-freesurfer_3_11_2025.csv')
qc = pd.read_csv('final_adni_qc.csv')
freesurfer
# Out:
#       Image Data ID     Subject Group Sex  Age Visit Modality  \
# 0           I185652  002_S_0295    CN   M   88   m36      MRI
# 1           I177650  002_S_0295    CN   M   86   m12      MRI
# 2           I178296  002_S_0295    CN   M   85   m06      MRI
# 3           I177659  002_S_0295    CN   M   87   m24      MRI
# 4           I167590  002_S_0295    CN   M   85    sc      MRI
# ...             ...         ...   ...  ..  ...   ...      ...
# 18658       I173270  941_S_1311   MCI   M   69    sc      MRI
# 18659       I222555  941_S_1311   MCI   M   69    sc      MRI
# 18660       I185315  941_S_1363   MCI   F   70    sc      MRI
# 18661       I185317  941_S_1363   MCI   F   70    sc      MRI
# 18662       I185316  941_S_1363   MCI   F   70    sc      MRI
#
#                                             Description            Type  \
# 0      FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
# 1       FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 2        FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# 3      FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
# 4       FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# ...                                                 ...             ...
# 18658    FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# 18659       FreeSurfer Longitudinal Processing surfaces  Post-processed
# 18660    FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# 18661   FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 18662  FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
#
#         Acq Date Format Downloaded
# 0      5/22/2009    MGH        NaN
# 1      5/25/2007    MGH        NaN
# 2      11/2/2006     FS        NaN
# 3      7/23/2008    MGH        NaN
# 4      4/18/2006    MGH  2/12/2025
# ...          ...    ...        ...
# 18658   3/2/2007     FS  2/12/2025
# 18659   3/2/2007     FS        NaN
# 18660  3/12/2007     FS  2/12/2025
# 18661  3/12/2007    MGH  2/12/2025
# 18662  3/12/2007    MGH  2/12/2025
#
# [18663 rows x 12 columns]

# %%
qc
# Out:
#        RID VISCODE VISCODE2    STATUS OVERALLQC
# 0       21     v11      m84  complete      Pass
# 1       21      nv      m60  complete      Pass
# 2       21     v06      m72  complete      Pass
# 3       23     v06      m72  complete      Pass
# 4       23      nv      m60  complete      Pass
# ...    ...     ...      ...       ...       ...
# 2286  5277     v02    scmri  complete      Pass
# 2287  5278     v02    scmri  complete      Pass
# 2288  5279     v02    scmri  complete      Pass
# 2289  5285     v02    scmri  complete      Pass
# 2290  5289     v05      m06  complete      Pass
#
# [2291 rows x 5 columns]

# %%
# in subject column for freesurfer, keep only characters that come after second underscore, and convert to int64
freesurfer['Subject'] = freesurfer['Subject'].str.split('_').str[2].astype('int64')
freesurfer
# Out:
#       Image Data ID  Subject Group Sex  Age Visit Modality  \
# 0           I185652      295    CN   M   88   m36      MRI
# 1           I177650      295    CN   M   86   m12      MRI
# 2           I178296      295    CN   M   85   m06      MRI
# 3           I177659      295    CN   M   87   m24      MRI
# 4           I167590      295    CN   M   85    sc      MRI
# ...             ...      ...   ...  ..  ...   ...      ...
# 18658       I173270     1311   MCI   M   69    sc      MRI
# 18659       I222555     1311   MCI   M   69    sc      MRI
# 18660       I185315     1363   MCI   F   70    sc      MRI
# 18661       I185317     1363   MCI   F   70    sc      MRI
# 18662       I185316     1363   MCI   F   70    sc      MRI
#
#                                             Description            Type  \
# 0      FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
# 1       FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 2        FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# 3      FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
# 4       FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# ...                                                 ...             ...
# 18658    FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# 18659       FreeSurfer Longitudinal Processing surfaces  Post-processed
# 18660    FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# 18661   FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 18662  FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
#
#         Acq Date Format Downloaded
# 0      5/22/2009    MGH        NaN
# 1      5/25/2007    MGH        NaN
# 2      11/2/2006     FS        NaN
# 3      7/23/2008    MGH        NaN
# 4      4/18/2006    MGH  2/12/2025
# ...          ...    ...        ...
# 18658   3/2/2007     FS  2/12/2025
# 18659   3/2/2007     FS        NaN
# 18660  3/12/2007     FS  2/12/2025
# 18661  3/12/2007    MGH  2/12/2025
# 18662  3/12/2007    MGH  2/12/2025
#
# [18663 rows x 12 columns]

# %%
freesurfer.dtypes
# Out:
# Image Data ID    object
# Subject           int64
# Group            object
# Sex              object
# Age               int64
# Visit            object
# Modality         object
# Description      object
# Type             object
# Acq Date         object
# Format           object
# Downloaded       object
# dtype: object

# %%
# rename Subject column to RID and Visit column to VISCODE2
freesurfer = freesurfer.rename(columns={'Subject':'RID', 'Visit':'VISCODE2'})
freesurfer
# Out:
#       Image Data ID   RID Group Sex  Age VISCODE2 Modality  \
# 0           I185652   295    CN   M   88      m36      MRI
# 1           I177650   295    CN   M   86      m12      MRI
# 2           I178296   295    CN   M   85      m06      MRI
# 3           I177659   295    CN   M   87      m24      MRI
# 4           I167590   295    CN   M   85       sc      MRI
# ...             ...   ...   ...  ..  ...      ...      ...
# 18658       I173270  1311   MCI   M   69       sc      MRI
# 18659       I222555  1311   MCI   M   69       sc      MRI
# 18660       I185315  1363   MCI   F   70       sc      MRI
# 18661       I185317  1363   MCI   F   70       sc      MRI
# 18662       I185316  1363   MCI   F   70       sc      MRI
#
#                                             Description            Type  \
# 0      FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
# 1       FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 2        FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# 3      FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
# 4       FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# ...                                                 ...             ...
# 18658    FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# 18659       FreeSurfer Longitudinal Processing surfaces  Post-processed
# 18660    FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# 18661   FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 18662  FreeSurfer Cross-Sectional Processing aparc+aseg  Post-processed
#
#         Acq Date Format Downloaded
# 0      5/22/2009    MGH        NaN
# 1      5/25/2007    MGH        NaN
# 2      11/2/2006     FS        NaN
# 3      7/23/2008    MGH        NaN
# 4      4/18/2006    MGH  2/12/2025
# ...          ...    ...        ...
# 18658   3/2/2007     FS  2/12/2025
# 18659   3/2/2007     FS        NaN
# 18660  3/12/2007     FS  2/12/2025
# 18661  3/12/2007    MGH  2/12/2025
# 18662  3/12/2007    MGH  2/12/2025
#
# [18663 rows x 12 columns]

# %%
# print dtypes for both dataframes
print(freesurfer.dtypes)
print(qc.dtypes)
# Out:
# Image Data ID    object
# RID               int64
# Group            object
# Sex              object
# Age               int64
# VISCODE2         object
# Modality         object
# Description      object
# Type             object
# Acq Date         object
# Format           object
# Downloaded       object
# dtype: object
# RID           int64
# VISCODE      object
# VISCODE2     object
# STATUS       object
# OVERALLQC    object
# dtype: object

# %%
# merge freesurfer and qc dataframes on RID and VISCODE2
merged = pd.merge(qc, freesurfer, on=['RID'])
merged
# Out:
#        RID VISCODE VISCODE2_x    STATUS OVERALLQC Image Data ID Group Sex  \
# 0       21     v11        m84  complete      Pass       I252191    CN   F
# 1       21     v11        m84  complete      Pass       I198610    CN   F
# 2       21     v11        m84  complete      Pass       I198603    CN   F
# 3       21     v11        m84  complete      Pass       I178379    CN   F
# 4       21     v11        m84  complete      Pass       I177481    CN   F
# ...    ...     ...        ...       ...       ...           ...   ...  ..
# 1690  1282      nv        m48  complete      Pass       I198663   MCI   F
# 1691  1282      nv        m48  complete      Pass       I177350   MCI   F
# 1692  1282      nv        m48  complete      Pass       I198656   MCI   F
# 1693  1282      nv        m48  complete      Pass       I198649   MCI   F
# 1694  1282      nv        m48  complete      Pass       I177584   MCI   F
#
#       Age VISCODE2_y Modality  \
# 0      75        m24      MRI
# 1      76        m36      MRI
# 2      73         sc      MRI
# 3      73        m06      MRI
# 4      73         sc      MRI
# ...   ...        ...      ...
# 1690   79        m24      MRI
# 1691   78        m06      MRI
# 1692   78        m12      MRI
# 1693   77         sc      MRI
# 1694   79        m24      MRI
#
#                                           Description            Type  \
# 0     FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 1        FreeSurfer Longitudinal Processing brainmask  Post-processed
# 2         FreeSurfer Longitudinal Processing surfaces  Post-processed
# 3     FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 4      FreeSurfer Cross-Sectional Processing surfaces  Post-processed
# ...                                               ...             ...
# 1690      FreeSurfer Longitudinal Processing surfaces  Post-processed
# 1691  FreeSurfer Cross-Sectional Processing brainmask  Post-processed
# 1692      FreeSurfer Longitudinal Processing surfaces  Post-processed
# 1693     FreeSurfer Longitudinal Processing brainmask  Post-processed
# 1694  FreeSurfer Cross-Sectional Processing brainmask  Post-processed
#
#         Acq Date Format Downloaded
# 0     11/12/2007    MGH        NaN
# 1     10/23/2008    MGH        NaN
# 2     10/10/2005     FS        NaN
# 3      4/24/2006    MGH        NaN
# 4     10/10/2005     FS        NaN
# ...          ...    ...        ...
# 1690   2/26/2009     FS        NaN
# 1691   8/31/2007    MGH  2/12/2025
# 1692   2/19/2008     FS        NaN
# 1693    2/9/2007    MGH        NaN
# 1694   2/26/2009    MGH        NaN
#
# [1695 rows x 16 columns]

# %%
# count number of unique values in RID column for merged dataframe
merged['RID'].nunique()
# Out:
# 37
